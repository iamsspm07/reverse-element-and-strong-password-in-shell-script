# %% [markdown]
# ## **Problem 01**
#
# ### **Reverse the given number**
#
# Write a shell script function to return a number in reverse order. It should support the following requirements.
#
# * The script should accept the input from the user line.
# * If you don’t input any data, then display an error message to execute the script correctly.

# %% [markdown]
# ![Code Reverse.png](data:image/png;base64,...)

# %% [markdown]
# ![Outputs.png](data:image/png;base64,...)

# %% [markdown]
# ```shell
# # run
# ./reverse.sh
# # output
# Enter a number to reverse: 1234
# Reversed number: 4321
# ```

# %% [markdown]
# ## **Problem 02**
#
# ### **Validate Password Strength**
#
# Write a shell script to validate password strength. Here are a few assumptions for the password string.
#
# * Length  – minimum of 8 characters.
# * Contain both alphabet and number.
# * Include both the small and capital case letters.
#
# If the password doesn’t comply with any of the above conditions, then the script should report it as a **Weak Password -> \<Should include so and so\>**

# %% [markdown]
# ![StrongPassword.png](data:image/png;base64,...)

# %% [markdown]
# ![StrOutput.png](data:image/png;base64,...)

# %% [markdown]
# ```shell
# # run
# ./validate_password_strength.sh
# # output
# Enter the password: Npci1234
# Strong Password
#
# Enter the password: npci123
# Weak Password -> Password length should have at least 8 characters.
#
# Enter the password: NPCI1234
# Weak Password -> Should include a lower case letter.
# ```
